# %% [markdown]
# <a href="https://colab.research.google.com/github/dfukagaw28/ColabNotebooks/blob/main/Colab_%E3%81%A7_iiif_prezi3_%E3%82%92%E4%BD%BF%E3%81%A3%E3%81%A6%E3%81%BF%E3%82%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab で iiif-prezi3 を使ってみる

# %% [markdown]
# ## まとめ
#
# *   [iiif-prezi3](https://iiif-prezi.github.io/iiif-prezi3/) は iiif-prezi の後継で，IIIF Presentation API 3.0 に対応しているらしい
# *   Colab で iiif-prezi3 を利用しようとすると，インストールエラーが発生する
#     *   原因はパッケージの依存関係の不整合
#     *   iiif-prezi3 が要求するのは `pydantic<2.0.0,>=1.9.2`
#     *   Colab にプリインストールされているパッケージの多くは 2.0 以上を要求する
#         *   albumentations (>=2.9.2): 機械学習分野で人気の、画像データ拡張ライブラリ
#         *   google-genai (>=2.0.0): Gemini API を使うためのライブラリ
#         *   thinc (>=2.0.0): lightweight deep learning library
#         *   langchain (>=2.7.4), langchain-core (>=2.5.2): LLM 開発のためのライブラリ
# *   依存関係を書き換えれば，無理やり「インストール」することはできる
#     *   ただしコードをあちこち書き換えないとテストをパスできない
#     *   実際に使うこともできない
# *   問題となるパッケージを削除すれば使える

# %%
# !pip list | grep pydantic
# Out:
# pydantic                              2.11.4
# pydantic_core                         2.33.2

# %%
# !pip install iiif-prezi3
# Out:
# Collecting iiif-prezi3
#   Downloading iiif_prezi3-2.0.1-py3-none-any.whl.metadata (8.0 kB)
# Collecting pydantic<2.0.0,>=1.9.2 (from iiif-prezi3)
#   Downloading pydantic-1.10.22-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /usr/local/lib/python3.11/dist-packages (from iiif-prezi3) (2.32.3)
# Requirement already satisfied: Pillow<=12.0.0,>=9.1.1 in /usr/local/lib/python3.11/dist-packages (from iiif-prezi3) (11.2.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.0.0,>=1.9.2->iiif-prezi3) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.28.0->iiif-prezi3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.28.0->iiif-prezi3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.28.0->iiif-prezi3) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.28.0->iiif-prezi3) (2025.4.26)
# Downloading iiif_prezi3-2.0.1-py3-none-any.whl (28 kB)
# Downloading pydantic-1.10.22-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 36.8 MB/s eta 0:00:00
# Installing collected packages: pydantic, iiif-prezi3
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.4
#     Uninstalling pydantic-2.11.4:
#       Successfully uninstalled pydantic-2.11.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.25 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.22 which is incompatible.
# google-genai 1.15.0 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.22 which is incompatible.
# thinc 8.3.6 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.22 which is incompatible.
# albumentations 2.0.6 requires pydantic>=2.9.2, but you have pydantic 1.10.22 which is incompatible.
# langchain-core 0.3.59 requires pydantic<3.0.0,>=2.5.2; python_full_version < "3.12.4", but you have pydantic 1.10.22 which is incompatible.
# Successfully installed iiif-prezi3-2.0.1 pydantic-1.10.22

# %% [markdown]
# ## 無理やりインストールしてみる

# %% [markdown]
# *   依存関係の設定を書き換えれば「インストール」できる

# %%
# !pip uninstall -y iiif-prezi3
# !pip install 'pydantic>=2.0.0,<3.0.0'
# Out:
# Found existing installation: iiif-prezi3 2.0.1
# Uninstalling iiif-prezi3-2.0.1:
#   Successfully uninstalled iiif-prezi3-2.0.1
# Collecting pydantic<3.0.0,>=2.0.0
#   Downloading pydantic-2.11.5-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0) (0.4.0)
# Downloading pydantic-2.11.5-py3-none-any.whl (444 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.2/444.2 kB 10.3 MB/s eta 0:00:00
# Installing collected packages: pydantic
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.22
#     Uninstalling pydantic-1.10.22:
#       Successfully uninstalled pydantic-1.10.22
# Successfully installed pydantic-2.11.5

# %%
VERSION = '2.0.1'

# %cd /content
# !rm -rf iiif-prezi3
# !git clone https://github.com/iiif-prezi/iiif-prezi3.git
# !git checkout {VERSION}

# %cd /content/iiif-prezi3
# !echo {VERSION} > version.txt
# !sed -i 's/"pydantic >= 1.9.2, <2.0.0"/"pydantic >= 1.9.2, <3.0.0"/g' setup.py
# !python setup.py install
# Out:
# /content
# Cloning into 'iiif-prezi3'...
# remote: Enumerating objects: 4853, done.
# remote: Counting objects: 100% (673/673), done.
# remote: Compressing objects: 100% (266/266), done.
# remote: Total 4853 (delta 373), reused 472 (delta 271), pack-reused 4180 (from 2)
# Receiving objects: 100% (4853/4853), 2.67 MiB | 5.15 MiB/s, done.
# Resolving deltas: 100% (2990/2990), done.
# fatal: not a git repository (or any of the parent directories): .git
# /content/iiif-prezi3
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating iiif_prezi3.egg-info
# writing iiif_prezi3.egg-info/PKG-INFO
# writing dependency_links to iiif_prezi3.egg-info/dependency_links.txt
# writing requirements to iiif_prezi3.egg-info/requires.txt
# writing top-level names to iiif_prezi3.egg-info/top_level.txt
# writing manifest file 'iiif_prezi3.egg-info/SOURCES.txt'
# reading manifest file 'iiif_prezi3.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'iiif_prezi3.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/lib/iiif_prezi3
# copying iiif_prezi3/base.py -> build/lib/iiif_prezi3
# copying iiif_prezi3/loader.py -> build/lib/iiif_prezi3
# copying iiif_prezi3/__init__.py -> build/lib/iiif_prezi3
# copying iiif_prezi3/skeleton.py -> build/lib/iiif_prezi3
# creating build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/set_hwd_from_file.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/create_canvas_from_iiif.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/add_label.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/auto_fields.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/make_canvas.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/make_range.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/add_metadata.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/set_hwd.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/make_manifest.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/annotation_helpers.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/make_service.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/add_item.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/make_collection.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/add_service.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/to_reference.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/add_thumbnail.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/canvas_sizes.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/__init__.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/add_range.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/add_image.py -> build/lib/iiif_prezi3/helpers
# copying iiif_prezi3/helpers/set_hwd_from_iiif.py -> build/lib/iiif_prezi3/helpers
# creating build/lib/iiif_prezi3/extensions
# copying iiif_prezi3/extensions/example_extension.py -> build/lib/iiif_prezi3/extensions
# copying iiif_prezi3/extensions/__init__.py -> build/lib/iiif_prezi3/extensions
# creating build/lib/iiif_prezi3/config
# copying iiif_prezi3/config/config.py -> build/lib/iiif_prezi3/config
# copying iiif_prezi3/config/__init__.py -> build/lib/iiif_prezi3/config
# copying iiif_prezi3/config/extensions.json -> build/lib/iiif_prezi3/config
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/iiif_prezi3
# creating build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/set_hwd_from_file.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/create_canvas_from_iiif.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/add_label.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/auto_fields.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/make_canvas.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/make_range.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/add_metadata.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/set_hwd.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/make_manifest.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/annotation_helpers.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/make_service.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/add_item.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/make_collection.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/add_service.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/to_reference.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/add_thumbnail.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/canvas_sizes.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/__init__.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/add_range.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/add_image.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/helpers/set_hwd_from_iiif.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/helpers
# copying build/lib/iiif_prezi3/base.py -> build/bdist.linux-x86_64/egg/iiif_prezi3
# copying build/lib/iiif_prezi3/loader.py -> build/bdist.linux-x86_64/egg/iiif_prezi3
# copying build/lib/iiif_prezi3/__init__.py -> build/bdist.linux-x86_64/egg/iiif_prezi3
# creating build/bdist.linux-x86_64/egg/iiif_prezi3/extensions
# copying build/lib/iiif_prezi3/extensions/example_extension.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/extensions
# copying build/lib/iiif_prezi3/extensions/__init__.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/extensions
# creating build/bdist.linux-x86_64/egg/iiif_prezi3/config
# copying build/lib/iiif_prezi3/config/config.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/config
# copying build/lib/iiif_prezi3/config/extensions.json -> build/bdist.linux-x86_64/egg/iiif_prezi3/config
# copying build/lib/iiif_prezi3/config/__init__.py -> build/bdist.linux-x86_64/egg/iiif_prezi3/config
# copying build/lib/iiif_prezi3/skeleton.py -> build/bdist.linux-x86_64/egg/iiif_prezi3
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/set_hwd_from_file.py to set_hwd_from_file.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/create_canvas_from_iiif.py to create_canvas_from_iiif.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/add_label.py to add_label.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/auto_fields.py to auto_fields.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/make_canvas.py to make_canvas.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/make_range.py to make_range.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/add_metadata.py to add_metadata.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/set_hwd.py to set_hwd.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/make_manifest.py to make_manifest.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/annotation_helpers.py to annotation_helpers.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/make_service.py to make_service.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/add_item.py to add_item.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/make_collection.py to make_collection.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/add_service.py to add_service.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/to_reference.py to to_reference.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/add_thumbnail.py to add_thumbnail.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/canvas_sizes.py to canvas_sizes.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/add_range.py to add_range.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/add_image.py to add_image.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/helpers/set_hwd_from_iiif.py to set_hwd_from_iiif.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/base.py to base.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/loader.py to loader.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/extensions/example_extension.py to example_extension.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/extensions/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/config/config.py to config.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/config/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/iiif_prezi3/skeleton.py to skeleton.cpython-311.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying iiif_prezi3.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying iiif_prezi3.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying iiif_prezi3.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying iiif_prezi3.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying iiif_prezi3.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# iiif_prezi3.__pycache__.loader.cpython-311: module references __file__
# creating dist
# creating 'dist/iiif_prezi3-2.0.1-py3.11.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing iiif_prezi3-2.0.1-py3.11.egg
# creating /usr/local/lib/python3.11/dist-packages/iiif_prezi3-2.0.1-py3.11.egg
# Extracting iiif_prezi3-2.0.1-py3.11.egg to /usr/local/lib/python3.11/dist-packages
# Adding iiif-prezi3 2.0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.11/dist-packages/iiif_prezi3-2.0.1-py3.11.egg
# Processing dependencies for iiif-prezi3==2.0.1
# Searching for pillow==11.2.1
# Best match: pillow 11.2.1
# Adding pillow 11.2.1 to easy-install.pth file
# detected new path './iiif_prezi3-2.0.1-py3.11.egg'
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for requests==2.32.3
# Best match: requests 2.32.3
# Adding requests 2.32.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for pydantic==2.11.5
# Best match: pydantic 2.11.5
# Adding pydantic 2.11.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for certifi==2025.4.26
# Best match: certifi 2025.4.26
# Adding certifi 2025.4.26 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for urllib3==2.4.0
# Best match: urllib3 2.4.0
# Adding urllib3 2.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for idna==3.10
# Best match: idna 3.10
# Adding idna 3.10 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for charset-normalizer==3.4.2
# Best match: charset-normalizer 3.4.2
# Adding charset-normalizer 3.4.2 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for typing-inspection==0.4.0
# Best match: typing-inspection 0.4.0
# Adding typing-inspection 0.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for typing-extensions==4.13.2
# Best match: typing-extensions 4.13.2
# Adding typing-extensions 4.13.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for pydantic-core==2.33.2
# Best match: pydantic-core 2.33.2
# Adding pydantic-core 2.33.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for annotated-types==0.7.0
# Best match: annotated-types 0.7.0
# Adding annotated-types 0.7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Finished processing dependencies for iiif-prezi3==2.0.1

# %% [markdown]
# ## テスト

# %%
# !pip install 'pyproject-api>=1.8' 'packaging<25,>=24.2'
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/iiif_prezi3-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting pyproject-api>=1.8
#   Downloading pyproject_api-1.9.1-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: packaging<25,>=24.2 in /usr/local/lib/python3.11/dist-packages (24.2)
# INFO: pip is looking at multiple versions of pyproject-api to determine which version is compatible with other requirements. This could take a while.
#   Downloading pyproject_api-1.9.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading pyproject_api-1.9.0-py3-none-any.whl (13 kB)
# Installing collected packages: pyproject-api
# Successfully installed pyproject-api-1.9.0

# %%
# %cd /content/iiif-prezi3
# !pip install tox
# !tox
# Out:
# /content/iiif-prezi3
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/iiif_prezi3-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting tox
#   Downloading tox-4.26.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: cachetools>=5.5.1 in /usr/local/lib/python3.11/dist-packages (from tox) (5.5.2)
# Requirement already satisfied: chardet>=5.2 in /usr/local/lib/python3.11/dist-packages (from tox) (5.2.0)
# Collecting colorama>=0.4.6 (from tox)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.11/dist-packages (from tox) (3.18.0)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.11/dist-packages (from tox) (24.2)
# Requirement already satisfied: platformdirs>=4.3.6 in /usr/local/lib/python3.11/dist-packages (from tox) (4.3.8)
# Requirement already satisfied: pluggy>=1.5 in /usr/local/lib/python3.11/dist-packages (from tox) (1.5.0)
# Requirement already satisfied: pyproject-api>=1.8 in /usr/local/lib/python3.11/dist-packages (from tox) (1.9.0)
# Collecting virtualenv>=20.31 (from tox)
#   Downloading virtualenv-20.31.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.31->tox)
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Downloading tox-4.26.0-py3-none-any.whl (172 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.8/172.8 kB 5.0 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading virtualenv-20.31.2-py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 73.7 MB/s eta 0:00:00
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 31.0 MB/s eta 0:00:00
# Installing collected packages: distlib, virtualenv, colorama, tox
# Successfully installed colorama-0.4.6 distlib-0.3.9 tox-4.26.0 virtualenv-20.31.2
# py39: skipped because could not find python interpreter with spec(s): py39
# py39: SKIP ⚠ in 0.28 seconds
# py310: Tox core option 'requires' is missing or does not specify keyrings.google-artifactregistry-auth. Package will not be installed in testenv
# .pkg: Tox core option 'requires' is missing or does not specify keyrings.google-artifactregistry-auth. Package will not be installed in testenv
# .pkg: install_requires> python -I -m pip install 'setuptools>=40.8.0' wheel
# .pkg: Tox core option 'requires' is missing or does not specify keyrings.google-artifactregistry-auth. Package will not be installed in testenv
# .pkg: _optional_hooks> python /usr/local/lib/python3.11/dist-packages/pyproject_api/_backend.py True setuptools.build_meta __legacy__
# .pkg: get_requires_for_build_sdist> python /usr/local/lib/python3.11/dist-packages/pyproject_api/_backend.py True setuptools.build_meta __legacy__
# .pkg: Tox core option 'requires' is missing or does not specify keyrings.google-artifactregistry-auth. Package will not be installed in testenv
# .pkg: get_requires_for_build_wheel> python /usr/local/lib/python3.11/dist-packages/pyproject_api/_backend.py True setuptools.build_meta __legacy__
# .pkg: Tox core option 'requires' is missing or does not specify keyrings.google-artifactregistry-auth. Package will not be installed in testenv
# .pkg: prepare_metadata_for_build_wheel> python /usr/local/lib/python3.11/dist-packages/pyproject_api/_backend.py True setuptools.build_meta __legacy__
# .pkg: build_sdist> python /usr/local/lib/python3.11/dist-packages/pyproject_api/_backend.py True setuptools.build_meta __legacy__
# py310: Tox core option 'requires' is missing or does not specify keyrings.google-artifactregistry-auth. Package will not be installed in testenv
# py310: install_package_deps> python -I -m pip install 'Pillow<=12.0.0,>=9.1.1' 'pydantic<3.0.0,>=1.9.2' 'requests<3.0.0,>=2.28.0'
# py310: install_package> python -I -m pip install --force-reinstall --no-deps /content/iiif-prezi3/.tox/.tmp/package/1/iiif_prezi3-2.0.1.tar.gz
# py310: commands[0]> python -m unittest discover -s tests
# /content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_config.py:373: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'validate_by_name'
# * 'validate_all' has been renamed to 'validate_default'
# * 'copy_on_model_validation' has been removed
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)
# /content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_config.py:373: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'validate_by_name'
# * 'validate_all' has been renamed to 'validate_default'
# * 'copy_on_model_validation' has been removed
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)
# EEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: test_add_item (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_add_item
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_add_item.py", line 5, in <module>
#     from iiif_prezi3 import (AccompanyingCanvas, Annotation, AnnotationPage,
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_add_metadata (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_add_metadata
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_add_metadata.py", line 3, in <module>
#     from iiif_prezi3 import Collection, LngString
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_add_range (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_add_range
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_add_range.py", line 3, in <module>
#     from iiif_prezi3 import Manifest, Range
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_add_service (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_add_service
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_add_service.py", line 3, in <module>
#     from iiif_prezi3 import (Annotation, AnnotationCollection, AnnotationPage,
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_add_thumbnail (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_add_thumbnail
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_add_thumbnail.py", line 4, in <module>
#     from iiif_prezi3 import Manifest
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_annotation_helpers (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_annotation_helpers
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_annotation_helpers.py", line 3, in <module>
#     from iiif_prezi3 import Annotation, AnnotationPage, Manifest
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_basic (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_basic
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_basic.py", line 7, in <module>
#     from iiif_prezi3 import Canvas, Manifest
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_canvas_helpers (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_canvas_helpers
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_canvas_helpers.py", line 3, in <module>
#     from iiif_prezi3 import AnnotationPage, Canvas, ResourceItem
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_create_canvas_from_iiif (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_create_canvas_from_iiif
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_create_canvas_from_iiif.py", line 4, in <module>
#     from iiif_prezi3 import Manifest
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_extensions (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_extensions
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_extensions.py", line 4, in <module>
#     import iiif_prezi3
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_helpers_addlabel (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_helpers_addlabel
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_helpers_addlabel.py", line 3, in <module>
#     from iiif_prezi3 import Canvas, config
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_helpers_autofields (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_helpers_autofields
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_helpers_autofields.py", line 3, in <module>
#     from iiif_prezi3 import Collection, Manifest, config
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_make_canvas (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_make_canvas
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_make_canvas.py", line 3, in <module>
#     from iiif_prezi3 import Canvas, Manifest
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_make_collection (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_make_collection
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_make_collection.py", line 3, in <module>
#     from iiif_prezi3 import Collection
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_make_manifest (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_make_manifest
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_make_manifest.py", line 3, in <module>
#     from iiif_prezi3 import Collection, HomepageItem, Reference, config
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_make_range (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_make_range
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_make_range.py", line 3, in <module>
#     from iiif_prezi3 import Manifest, Range
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_make_service (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_make_service
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_make_service.py", line 3, in <module>
#     from iiif_prezi3 import (Annotation, AnnotationCollection, AnnotationPage,
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_set_hwd (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_set_hwd
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_set_hwd.py", line 6, in <module>
#     from iiif_prezi3 import Canvas
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_set_hwd_from_file_helper (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_set_hwd_from_file_helper
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_set_hwd_from_file_helper.py", line 3, in <module>
#     from iiif_prezi3 import Canvas
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_set_hwd_from_iiif (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_set_hwd_from_iiif
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/unittest/loader.py", line 436, in _find_test_path
#     module = self._get_module_from_name(name)
#   File "/usr/lib/python3.10/unittest/loader.py", line 377, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_set_hwd_from_iiif.py", line 6, in <module>
#     from iiif_prezi3 import Canvas
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#   File "/content/iiif-prezi3/.tox/py310/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ----------------------------------------------------------------------
# Ran 20 tests in 0.004s
#
# FAILED (errors=20)
# py310: exit 1 (0.58 seconds) /content/iiif-prezi3> python -m unittest discover -s tests pid=721
# py310: FAIL ✖ in 21.3 seconds
# py311: Tox core option 'requires' is missing or does not specify keyrings.google-artifactregistry-auth. Package will not be installed in testenv
# py311: Tox core option 'requires' is missing or does not specify keyrings.google-artifactregistry-auth. Package will not be installed in testenv
# py311: install_package_deps> python -I -m pip install 'Pillow<=12.0.0,>=9.1.1' 'pydantic<3.0.0,>=1.9.2' 'requests<3.0.0,>=2.28.0'
# py311: install_package> python -I -m pip install --force-reinstall --no-deps /content/iiif-prezi3/.tox/.tmp/package/2/iiif_prezi3-2.0.1.tar.gz
# py311: commands[0]> python -m unittest discover -s tests
# /content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_config.py:373: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'validate_by_name'
# * 'validate_all' has been renamed to 'validate_default'
# * 'copy_on_model_validation' has been removed
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)
# /content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_config.py:373: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'validate_by_name'
# * 'validate_all' has been renamed to 'validate_default'
# * 'copy_on_model_validation' has been removed
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)
# EEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: test_add_item (unittest.loader._FailedTest.test_add_item)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_add_item
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/unittest/loader.py", line 419, in _find_test_path
#     module = self._get_module_from_name(name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/unittest/loader.py", line 362, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_add_item.py", line 5, in <module>
#     from iiif_prezi3 import (AccompanyingCanvas, Annotation, AnnotationPage,
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#                          ^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_add_metadata (unittest.loader._FailedTest.test_add_metadata)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_add_metadata
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/unittest/loader.py", line 419, in _find_test_path
#     module = self._get_module_from_name(name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/unittest/loader.py", line 362, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_add_metadata.py", line 3, in <module>
#     from iiif_prezi3 import Collection, LngString
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#                          ^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_add_range (unittest.loader._FailedTest.test_add_range)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_add_range
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/unittest/loader.py", line 419, in _find_test_path
#     module = self._get_module_from_name(name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/unittest/loader.py", line 362, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_add_range.py", line 3, in <module>
#     from iiif_prezi3 import Manifest, Range
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#                          ^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_add_service (unittest.loader._FailedTest.test_add_service)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_add_service
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/unittest/loader.py", line 419, in _find_test_path
#     module = self._get_module_from_name(name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/unittest/loader.py", line 362, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_add_service.py", line 3, in <module>
#     from iiif_prezi3 import (Annotation, AnnotationCollection, AnnotationPage,
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
# ...
#     from .add_image import AddImage  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#                          ^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_make_collection (unittest.loader._FailedTest.test_make_collection)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_make_collection
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/unittest/loader.py", line 419, in _find_test_path
#     module = self._get_module_from_name(name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/unittest/loader.py", line 362, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_make_collection.py", line 3, in <module>
#     from iiif_prezi3 import Collection
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#                          ^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_make_manifest (unittest.loader._FailedTest.test_make_manifest)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_make_manifest
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/unittest/loader.py", line 419, in _find_test_path
#     module = self._get_module_from_name(name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/unittest/loader.py", line 362, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_make_manifest.py", line 3, in <module>
#     from iiif_prezi3 import Collection, HomepageItem, Reference, config
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#                          ^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_make_range (unittest.loader._FailedTest.test_make_range)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_make_range
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/unittest/loader.py", line 419, in _find_test_path
#     module = self._get_module_from_name(name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/unittest/loader.py", line 362, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_make_range.py", line 3, in <module>
#     from iiif_prezi3 import Manifest, Range
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#                          ^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_make_service (unittest.loader._FailedTest.test_make_service)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_make_service
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/unittest/loader.py", line 419, in _find_test_path
#     module = self._get_module_from_name(name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/unittest/loader.py", line 362, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_make_service.py", line 3, in <module>
#     from iiif_prezi3 import (Annotation, AnnotationCollection, AnnotationPage,
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#                          ^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_set_hwd (unittest.loader._FailedTest.test_set_hwd)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_set_hwd
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/unittest/loader.py", line 419, in _find_test_path
#     module = self._get_module_from_name(name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/unittest/loader.py", line 362, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_set_hwd.py", line 6, in <module>
#     from iiif_prezi3 import Canvas
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#                          ^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_set_hwd_from_file_helper (unittest.loader._FailedTest.test_set_hwd_from_file_helper)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_set_hwd_from_file_helper
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/unittest/loader.py", line 419, in _find_test_path
#     module = self._get_module_from_name(name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/unittest/loader.py", line 362, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_set_hwd_from_file_helper.py", line 3, in <module>
#     from iiif_prezi3 import Canvas
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#                          ^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ======================================================================
# ERROR: test_set_hwd_from_iiif (unittest.loader._FailedTest.test_set_hwd_from_iiif)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: test_set_hwd_from_iiif
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/unittest/loader.py", line 419, in _find_test_path
#     module = self._get_module_from_name(name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/unittest/loader.py", line 362, in _get_module_from_name
#     __import__(name)
#   File "/content/iiif-prezi3/tests/test_set_hwd_from_iiif.py", line 6, in <module>
#     from iiif_prezi3 import Canvas
#   File "/content/iiif-prezi3/iiif_prezi3/__init__.py", line 1, in <module>
#     from iiif_prezi3.helpers import *  # noqa: F401,F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/__init__.py", line 1, in <module>
#     from .add_image import AddImage  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/iiif_prezi3/helpers/add_image.py", line 2, in <module>
#     from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#   File "/content/iiif-prezi3/iiif_prezi3/skeleton.py", line 15, in <module>
#     class Behavior(Base):
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 112, in __new__
#     private_attributes = inspect_namespace(
#                          ^^^^^^^^^^^^^^^^^^
#   File "/content/iiif-prezi3/.tox/py311/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py", line 402, in inspect_namespace
#     raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'
#
#
# ----------------------------------------------------------------------
# Ran 20 tests in 0.002s
#
# FAILED (errors=20)
# py311: exit 1 (0.58 seconds) /content/iiif-prezi3> python -m unittest discover -s tests pid=853
# py311: FAIL ✖ in 13.65 seconds
# linting: Tox core option 'requires' is missing or does not specify keyrings.google-artifactregistry-auth. Package will not be installed in testenv
# linting: Tox core option 'requires' is missing or does not specify keyrings.google-artifactregistry-auth. Package will not be installed in testenv
# linting: install_package_deps> python -I -m pip install 'Pillow<=12.0.0,>=9.1.1' 'autopep8<3.0.0,>=1.6.0' 'datamodel-code-generator<1.0.0,>=0.17.1' 'deepdiff<9.0.0,>=6.2.2' 'flake8-docstrings<2.0.0,>=1.6.0' 'flake8-isort<7.0.0,>=4.1.1' 'flake8<8.0.0,>=7.2.0' 'isort<6.0.0,>=5.10.1' 'pydantic<3.0.0,>=1.9.2' 'requests<3.0.0,>=2.28.0' 'tox<5.0.0,>=3.25.0'
# linting: install_package> python -I -m pip install --force-reinstall --no-deps /content/iiif-prezi3/.tox/.tmp/package/3/iiif_prezi3-2.0.1.tar.gz
# linting: commands[0]> isort .
# Skipped 4 files
# linting: commands[1]> autopep8 --in-place --recursive --exclude skeleton.py --ignore E501 .
# linting: commands[2]> flake8
# linting: OK ✔ in 24.75 seconds
# py312: skipped because could not find python interpreter with spec(s): py312
# py312: SKIP ⚠ in 0.01 seconds
# py313: skipped because could not find python interpreter with spec(s): py313
#   py39: SKIP (0.28 seconds)
#   py310: FAIL code 1 (21.30=setup[20.72]+cmd[0.58] seconds)
#   py311: FAIL code 1 (13.65=setup[13.06]+cmd[0.58] seconds)
#   linting: OK (24.75=setup[21.70]+cmd[0.23,1.75,1.08] seconds)
#   py312: SKIP (0.01 seconds)
#   py313: SKIP (0.01 seconds)
#   evaluation failed :( (60.18 seconds)

# %% [markdown]
# ## 使ってみる（失敗する）

# %%
from iiif_prezi3 import Manifest
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_config.py:373: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'validate_by_name'
# * 'validate_all' has been renamed to 'validate_default'
# * 'copy_on_model_validation' has been removed
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-707b0f25e7bd> in <cell line: 0>()
# ----> 1 from iiif_prezi3 import Manifest
#
# /content/iiif-prezi3/iiif_prezi3/__init__.py in <module>
# ----> 1 from iiif_prezi3.helpers import *  # noqa: F401,F403
#       2
#       3 from .loader import load_bundled_extensions  # noqa: F401
#       4 from .skeleton import *  # noqa: F401,F403
#
# /content/iiif-prezi3/iiif_prezi3/helpers/__init__.py in <module>
# ----> 1 from .add_image import AddImage  # noqa: F401
#       2 from .add_item import AddItem, AddItemByReference  # noqa: F401
#       3 from .add_label import AddLabel  # noqa: F401
#       4 from .add_metadata import AddMetadata  # noqa: F401
#       5 from .add_range import AddRange  # noqa: F401
#
# /content/iiif-prezi3/iiif_prezi3/helpers/add_image.py in <module>
#       1 from ..loader import monkeypatch_schema
# ----> 2 from ..skeleton import (AccompanyingCanvas, Annotation, AnnotationPage, Canvas,
#       3                         PlaceholderCanvas, ResourceItem)
#       4
#       5
#
# /content/iiif-prezi3/iiif_prezi3/skeleton.py in <module>
#      13
#      14
# ---> 15 class Behavior(Base):
#      16     __root__: List[
#      17         Union[
#
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_model_construction.py in __new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     110             config_wrapper = ConfigWrapper.for_model(bases, namespace, kwargs)
#     111             namespace['model_config'] = config_wrapper.config_dict
# --> 112             private_attributes = inspect_namespace(
#     113                 namespace, config_wrapper.ignored_types, class_vars, base_field_names
#     114             )
#
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_model_construction.py in inspect_namespace(namespace, ignored_types, base_class_vars, base_class_fields)
#     400
#     401     if '__root__' in raw_annotations or '__root__' in namespace:
# --> 402         raise TypeError("To define root models, use `pydantic.RootModel` rather than a field called '__root__'")
#     403
#     404     ignored_names: set[str] = set()
#
# TypeError: To define root models, use `pydantic.RootModel` rather than a field called '__root__'

# %% [markdown]
# ## 不要なパッケージを削除して iiif-prezi3 をインストールする

# %%
# !pip uninstall -y albumentations google-genai langchain langchain-core thinc
# Out:
# Found existing installation: albumentations 2.0.6
# Uninstalling albumentations-2.0.6:
#   Successfully uninstalled albumentations-2.0.6
# Found existing installation: google-genai 1.15.0
# Uninstalling google-genai-1.15.0:
#   Successfully uninstalled google-genai-1.15.0
# Found existing installation: langchain 0.3.25
# Uninstalling langchain-0.3.25:
#   Successfully uninstalled langchain-0.3.25
# Found existing installation: langchain-core 0.3.59
# Uninstalling langchain-core-0.3.59:
#   Successfully uninstalled langchain-core-0.3.59
# Found existing installation: thinc 8.3.6
# Uninstalling thinc-8.3.6:
#   Successfully uninstalled thinc-8.3.6

# %%
# !pip uninstall -y iiif-prezi3
# !pip install iiif-prezi3
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/iiif_prezi3-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Found existing installation: iiif-prezi3 2.0.1
# Uninstalling iiif-prezi3-2.0.1:
#   Successfully uninstalled iiif-prezi3-2.0.1
# Collecting iiif-prezi3
#   Using cached iiif_prezi3-2.0.1-py3-none-any.whl.metadata (8.0 kB)
# Collecting pydantic<2.0.0,>=1.9.2 (from iiif-prezi3)
#   Using cached pydantic-1.10.22-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (154 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /usr/local/lib/python3.11/dist-packages (from iiif-prezi3) (2.32.3)
# Requirement already satisfied: Pillow<=12.0.0,>=9.1.1 in /usr/local/lib/python3.11/dist-packages (from iiif-prezi3) (11.2.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.0.0,>=1.9.2->iiif-prezi3) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.28.0->iiif-prezi3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.28.0->iiif-prezi3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.28.0->iiif-prezi3) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.28.0->iiif-prezi3) (2025.4.26)
# Using cached iiif_prezi3-2.0.1-py3-none-any.whl (28 kB)
# Using cached pydantic-1.10.22-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Installing collected packages: pydantic, iiif-prezi3
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.5
#     Uninstalling pydantic-2.11.5:
#       Successfully uninstalled pydantic-2.11.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-aiplatform 1.92.0 requires google-genai<2.0.0,>=1.0.0, which is not installed.
# spacy 3.8.5 requires thinc<8.4.0,>=8.3.4, which is not installed.
# Successfully installed iiif-prezi3-2.0.1 pydantic-1.10.22

# %%
from iiif_prezi3 import Manifest

m = Manifest(id="https://example.com/iiif/manifest.json", label={"en":["Example Manifest"]})

print(m.json(indent=2))
# Out:
# {
#   "@context": "http://iiif.io/api/presentation/3/context.json",
#   "id": "https://example.com/iiif/manifest.json",
#   "type": "Manifest",
#   "label": {
#     "en": [
#       "Example Manifest"
#     ]
#   },
#   "items": []
# }
